# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain1947/Learn_By_Inventing_00/blob/main/0_01_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
2 + 3
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
7 / 2
# Out:
# 3.5

# %%
2 ** 10
# Out:
# 1024

# %%
name = "Khaddim"
print("Hello, " + name + "!")
# Out:
# Hello, Khaddim!

# %%
print(3 + 4)
print("3 + 4")
print("Result:", 3 + 4)
# Out:
# 7
# 3 + 4
# Result: 7

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "khaddim"
fav = 7

print(name, "likes the number", fav)
print(fav, "squared is", fav ** 2)
# Out:
# khaddim likes the number 7
# 7 squared is 49
